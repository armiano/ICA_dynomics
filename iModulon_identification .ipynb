# %%
import pandas as pd

# Load the dataset
data = pd.read_csv('Supplementary_Data_3.csv',index_col=0)

# Define a threshold (you would define a suitable value based on your data)
threshold = 0.2

# Initialize a dictionary to store the results
results = {}

# Iterate over each iModulon
for i, row in data.iterrows():
    max_amplitude = -1
    enriched_metal = None
    
    # Iterate over each heavy metal (assuming each metal corresponds to 6 columns)
    for j in range(0, data.shape[1], 6):
        # Calculate the amplitude for the current metal
        amplitude = row.iloc[j:j+6].max() - row.iloc[j:j+6].min()
        
        # Check if the amplitude exceeds the threshold and is the highest so far
        if amplitude > threshold and amplitude > max_amplitude:
            max_amplitude = amplitude
            enriched_metal = data.columns[j].split('_')[0]  # Assuming column names include metal names
    
    # Store the result for the current iModulon
    results[f'iModulon_{i+1}'] = enriched_metal if enriched_metal else 'No enrichment'

# Print the results
for iModulon, metal in results.items():
    print(f'{iModulon}: {metal}')
# Out:
# iModulon_1: Pb
# iModulon_2: Zn
# iModulon_3: Fe
# iModulon_4: Cd
# iModulon_5: Cr
# iModulon_6: Pb
# iModulon_7: Fe
# iModulon_8: Zn
# iModulon_9: Zn
# iModulon_10: Zn
# iModulon_11: Cu
# iModulon_12: Cr
# iModulon_13: Zn
# iModulon_14: Fe
# iModulon_15: Cu

# %%
import pandas as pd

# Load the dataset
data = pd.read_csv('Supplementary_Data_3.csv',index_col=0)

# Define a threshold for primary and secondary metal identification
primary_threshold = 0.5
secondary_threshold = 0.5

# Initialize a dictionary to store the results
results = {}

# Iterate over each iModulon
for i, row in data.iterrows():
    max_amplitude = -1
    enriched_metal = None

    # First loop to identify the primary metal
    for j in range(0, data.shape[1], 6):
        # Calculate the amplitude for the current metal
        amplitude = row.iloc[j:j+6].max() - row.iloc[j:j+6].min()
        
        # Check if the amplitude exceeds the primary threshold and is the highest so far
        if amplitude > primary_threshold and amplitude > max_amplitude:
            max_amplitude = amplitude
            enriched_metal = data.columns[j].split('_')[0]  # Assuming column names include metal names

    # Second loop to identify the secondary metals
    secondary_metals = []
    for j in range(0, data.shape[1], 6):
        # Calculate the amplitude for the current metal
        amplitude = row.iloc[j:j+6].max() - row.iloc[j:j+6].min()
        
        # Check if the amplitude exceeds the secondary threshold and the metal is not the primary metal
        if amplitude > secondary_threshold and data.columns[j].split('_')[0] != enriched_metal:
            secondary_metals.append(data.columns[j].split('_')[0])
    
    # Store the result for the current iModulon
    results[f'iModulon_{i+1}'] = {'Primary': enriched_metal if enriched_metal else 'No enrichment', 'Secondary': ", ".join(secondary_metals) if secondary_metals else 'No secondary enrichment'}

# Print the results
for iModulon, metal in results.items():
    print(f'{iModulon}: Primary - {metal["Primary"]}, Secondary - {metal["Secondary"]}')
# Out:
# iModulon_1: Primary - Pb, Secondary - No secondary enrichment
# iModulon_2: Primary - Zn, Secondary - No secondary enrichment
# iModulon_3: Primary - Fe, Secondary - No secondary enrichment
# iModulon_4: Primary - Cd, Secondary - No secondary enrichment
# iModulon_5: Primary - Cr, Secondary - No secondary enrichment
# iModulon_6: Primary - Pb, Secondary - No secondary enrichment
# iModulon_7: Primary - Fe, Secondary - No secondary enrichment
# iModulon_8: Primary - Zn, Secondary - No secondary enrichment
# iModulon_9: Primary - Zn, Secondary - No secondary enrichment
# iModulon_10: Primary - Zn, Secondary - No secondary enrichment
# iModulon_11: Primary - Cu, Secondary - No secondary enrichment
# iModulon_12: Primary - Cr, Secondary - No secondary enrichment
# iModulon_13: Primary - Zn, Secondary - No secondary enrichment
# iModulon_14: Primary - Fe, Secondary - Cu
# iModulon_15: Primary - Cu, Secondary - No secondary enrichment

# %%
import pandas as pd

# Load the dataset
data = pd.read_csv('Supplementary_Data_6.csv',index_col=0)

# Define a threshold for primary and secondary metal identification
primary_threshold = 0.5
secondary_threshold = 0.5

# Initialize a dictionary to store the results
results = {}

# Iterate over each iModulon
for i, row in data.iterrows():
    max_amplitude = -1
    enriched_metal = None

    # First loop to identify the primary metal
    for j in range(0, data.shape[1], 6):
        # Calculate the amplitude for the current metal
        amplitude = row.iloc[j:j+6].max() - row.iloc[j:j+6].min()
        
        # Check if the amplitude exceeds the primary threshold and is the highest so far
        if amplitude > primary_threshold and amplitude > max_amplitude:
            max_amplitude = amplitude
            enriched_metal = data.columns[j].split('_')[0]  # Assuming column names include metal names

    # Second loop to identify the secondary metals
    secondary_metals = []
    for j in range(0, data.shape[1], 6):
        # Calculate the amplitude for the current metal
        amplitude = row.iloc[j:j+6].max() - row.iloc[j:j+6].min()
        
        # Check if the amplitude exceeds the secondary threshold and the metal is not the primary metal
        if amplitude > secondary_threshold and data.columns[j].split('_')[0] != enriched_metal:
            secondary_metals.append(data.columns[j].split('_')[0])
    
    # Store the result for the current iModulon
    results[f'iModulon_{i+1}'] = {'Primary': enriched_metal if enriched_metal else 'No enrichment', 'Secondary': ", ".join(secondary_metals) if secondary_metals else 'No secondary enrichment'}

# Print the results
for iModulon, metal in results.items():
    print(f'{iModulon}: Primary - {metal["Primary"]}, Secondary - {metal["Secondary"]}')
# Out:
# iModulon_1: Primary - Cu, Secondary - Cd, Zn
# iModulon_2: Primary - Zn, Secondary - No secondary enrichment
# iModulon_3: Primary - Zn, Secondary - No secondary enrichment
# iModulon_4: Primary - Zn, Secondary - No secondary enrichment
# iModulon_5: Primary - Zn, Secondary - No secondary enrichment
# iModulon_6: Primary - Zn, Secondary - No secondary enrichment
# iModulon_7: Primary - Fe, Secondary - No secondary enrichment
# iModulon_8: Primary - Fe, Secondary - No secondary enrichment
# iModulon_9: Primary - Cd, Secondary - No secondary enrichment
# iModulon_10: Primary - Cu, Secondary - Zn
# iModulon_11: Primary - Zn, Secondary - Cr, Fe, Cd, Cu
# iModulon_12: Primary - Cu, Secondary - Zn, Zn
# iModulon_13: Primary - Pb, Secondary - No secondary enrichment
# iModulon_14: Primary - Zn, Secondary - No secondary enrichment
# iModulon_15: Primary - Cr, Secondary - Fe, Cu
# iModulon_16: Primary - Zn, Secondary - No secondary enrichment
# iModulon_17: Primary - Zn, Secondary - No secondary enrichment
# iModulon_18: Primary - Cr, Secondary - Fe, Fe
# iModulon_19: Primary - Fe, Secondary - Cr, Cd, Cu
# iModulon_20: Primary - Zn, Secondary - No secondary enrichment
# iModulon_21: Primary - Cr, Secondary - Fe, Cu, Cu
# iModulon_22: Primary - Cr, Secondary - No secondary enrichment
# iModulon_23: Primary - Cd, Secondary - Fe
# iModulon_24: Primary - Fe, Secondary - Cr, Pb
# iModulon_25: Primary - Fe, Secondary - Cr
# iModulon_26: Primary - Fe, Secondary - No secondary enrichment
# iModulon_27: Primary - Zn, Secondary - No secondary enrichment
# iModulon_28: Primary - Zn, Secondary - No secondary enrichment
# iModulon_29: Primary - Zn, Secondary - No secondary enrichment
# iModulon_30: Primary - Cr, Secondary - No secondary enrichment
# iModulon_31: Primary - Fe, Secondary - No secondary enrichment
# iModulon_32: Primary - Zn, Secondary - No secondary enrichment
# iModulon_33: Primary - Cd, Secondary - No secondary enrichment
# iModulon_34: Primary - Cd, Secondary - Cu
# iModulon_35: Primary - Pb, Secondary - Cu

# %%
# Identify heavy metal associated with each iModulon in Fig. 4

import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset

# Define a threshold (you would define a suitable value based on your data)
threshold = 0.5

# Initialize a dictionary to store the results
results = {}

# Get the list of heavy metals from the column names
metals = [col.split('_')[0] for col in data.columns[1::6]]

# Iterate over each iModulon
for i, row in data.iterrows():
    max_amplitude = -1
    enriched_metal = None
    
    # Iterate over each heavy metal
    for j, metal in enumerate(metals):
        # Calculate the amplitude for the current metal
        amplitude = row.iloc[j*6+1:(j+1)*6+1].max() - row.iloc[j*6+1:(j+1)*6+1].min()
        
        # Check if the amplitude exceeds the threshold and is the highest so far
        if amplitude > threshold and amplitude > max_amplitude:
            max_amplitude = amplitude
            enriched_metal = metal
    
    # Store the result for the current iModulon
    results[f'iModulon_{i}'] = enriched_metal if enriched_metal else 'No enrichment'

    # Plot the data for the current iModulon
    plt.figure()
    row[1:].plot(kind='bar')
    plt.title(f'iModulon {i}')
    plt.xlabel('Conditions')
    plt.ylabel('Expression Level')
    plt.grid(axis='y')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.savefig(f'iModulon_{i}.png')  # Save the plot as a PNG file
    plt.close()

# Print the results
for iModulon, metal in results.items():
    print(f'{iModulon}: {metal}')
# Out:
# iModulon_0: Pb
# iModulon_1: Zn
# iModulon_2: Fe
# iModulon_3: Cd
# iModulon_4: Cr
# iModulon_5: Pb
# iModulon_6: Fe
# iModulon_7: Zn
# iModulon_8: Zn
# iModulon_9: Zn
# iModulon_10: Cu
# iModulon_11: Cr
# iModulon_12: Zn
# iModulon_13: Fe
# iModulon_14: Cu

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
data = pd.read_csv('Supplementary_Data_6.csv')

# Define a threshold (you would define a suitable value based on your data)
threshold = 0.5

# Initialize a dictionary to store the results
results = {}

# Get the list of heavy metals from the column names
metals = [col.split('_')[0] for col in data.columns[1::6]]

# Iterate over each iModulon
for i, row in data.iterrows():
    max_amplitude = -1
    enriched_metal = None
    
    # Iterate over each heavy metal
    for j, metal in enumerate(metals):
        # Calculate the amplitude for the current metal
        amplitude = row.iloc[j*6+1:(j+1)*6+1].max() - row.iloc[j*6+1:(j+1)*6+1].min()
        
        # Check if the amplitude exceeds the threshold and is the highest so far
        if amplitude > threshold and amplitude > max_amplitude:
            max_amplitude = amplitude
            enriched_metal = metal
    
    # Store the result for the current iModulon
    results[f'iModulon_{i}'] = enriched_metal if enriched_metal else 'No enrichment'

    # Plot the data for the current iModulon
    plt.figure()
    row[1:].plot(kind='bar')
    plt.title(f'iModulon {i}')
    plt.xlabel('Conditions')
    plt.ylabel('Expression Level')
    plt.grid(axis='y')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.savefig(f'iModulon_{i}.png')  # Save the plot as a PNG file
    plt.close()

# Print the results
for iModulon, metal in results.items():
    print(f'{iModulon}: {metal}')
# Out:
# iModulon_0: Cu
# iModulon_1: Zn
# iModulon_2: Zn
# iModulon_3: Zn
# iModulon_4: Zn
# iModulon_5: Zn
# iModulon_6: Fe
# iModulon_7: Fe
# iModulon_8: Cd
# iModulon_9: Cu
# iModulon_10: Zn
# iModulon_11: Cu
# iModulon_12: Pb
# iModulon_13: Zn
# iModulon_14: Cr
# iModulon_15: Zn
# iModulon_16: Zn
# iModulon_17: Cr
# iModulon_18: Fe
# iModulon_19: Zn
# iModulon_20: Cr
# iModulon_21: Cr
# iModulon_22: Cd
# iModulon_23: Fe
# iModulon_24: Fe
# iModulon_25: Fe
# iModulon_26: Zn
# iModulon_27: Zn
# iModulon_28: Zn
# iModulon_29: Cr
# iModulon_30: Fe
# iModulon_31: Zn
# iModulon_32: Cd
# iModulon_33: Cd
# iModulon_34: Pb

# %%
# Define a dictionary to map heavy metals to their respective columns
import numpy as np

data = df

metal_columns = {
    'Cr': [f'Cr_{i}' for i in range(1, 7)],
    'Fe': [f'Fe_{i}' for i in range(1, 7)],
    'Cd': [f'Cd_{i}' for i in range(1, 7)],
    'Zn': [f'Zn_{i}' for i in range(1, 7)],
    'Cu': [f'Cu_{i}' for i in range(1, 7)],
    'Pb': [f'Pb_{i}' for i in range(1, 7)],
}

def calculate_center_of_mass(row):
    metal = row['enriched_metal']
    if metal in metal_columns:
        values = row[metal_columns[metal]].values
        indices = range(len(values))
        return sum(indices * values) / sum(values)
    else:
        return None

# Calculate the center of mass for each time series based on the enriched metal
data['center_of_mass'] = data.apply(calculate_center_of_mass, axis=1)

def calculate_highest_peak(row):
    metal = row['enriched_metal']
    if metal in metal_columns:
        values = row[metal_columns[metal]].values
        return np.argmax(values) + 1  # Adding 1 to make it 1-indexed
    else:
        return None

# Calculate the highest peak for each time series based on the enriched metal
data['highest_peak'] = data.apply(calculate_highest_peak, axis=1)


# Classify the shapes based on the combination of center of mass and highest peak
def classify_shapes(row):
    if row['center_of_mass'] is not None and row['highest_peak'] is not None:
        if row['center_of_mass'] <= 3 and row['highest_peak'] <= 3:
            return 'Fast Activation'
        elif row['center_of_mass'] <= 4 and row['highest_peak'] <= 4:
            return 'Intermediate Activation'
        elif row['center_of_mass'] <= 4 and row['highest_peak'] >= 5:
            return 'Steady Activation'
        else:
            return 'Mixed Activation'
    else:
        return 'No Activation'

data['shape_classification'] = data.apply(classify_shapes, axis=1)
data
# Out:
#     Unnamed: 0      Cr_1      Cr_2      Cr_3      Cr_4      Cr_5      Cr_6  \
# 0            0 -0.015613 -0.020039 -0.017416 -0.040085 -0.047364 -0.110323
# 1            1 -0.001092  0.004791  0.006773  0.006421  0.005756  0.004135
# 2            2 -0.006212 -0.005562  0.001467  0.019224 -0.005293 -0.024368
# 3            3 -0.003268 -0.021917 -0.046883 -0.070408 -0.079213 -0.081761
# 4            4 -0.016373 -0.030128 -0.025499 -0.006179 -0.079990 -0.092722
# 5            5 -0.007480 -0.006940 -0.008847 -0.002491  0.004950 -0.005239
# 6            6 -0.001620 -0.008785 -0.027382 -0.047351 -0.019500 -0.008529
# 7            7  0.002125  0.000322  0.008727  0.038010  0.051214  0.068949
# 8            8 -0.005628  0.006085  0.009695  0.009462  0.008223 -0.009658
# 9            9 -0.044939 -0.058680 -0.032273 -0.034284 -0.010543  0.137579
# 10          10 -0.004805  0.026757  0.041831  0.042270  0.038697  0.061849
# 11          11  0.016623  0.017744  0.024750  0.057088  0.058952  0.018202
# 12          12  0.018718  0.015326 -0.001704 -0.021532  0.002653 -0.006849
# 13          13 -0.000381  0.008589  0.005254 -0.011116 -0.041662 -0.063406
# 14          14 -0.001754  0.031926  0.004469 -0.021574  0.037538  0.161242
# 15          15 -0.001112 -0.012771 -0.007165  0.031015 -0.013235 -0.014412
# 16          16 -0.009852 -0.017970 -0.026239 -0.035737 -0.025486 -0.043295
# 17          17 -0.019541 -0.004054  0.024273  0.032887  0.084983  0.067684
# 18          18  0.057121  0.068260  0.061835  0.018151 -0.034861 -0.116442
# 19          19 -0.007794 -0.024792 -0.021147 -0.004489 -0.005098  0.008407
# 20          20 -0.067098 -0.170857 -0.204836 -0.072389  0.027840  0.168819
# 21          21  0.005193  0.015461  0.022072  0.013390  0.002745  0.013230
# 22          22 -0.006480 -0.022688 -0.027172 -0.031724 -0.052338 -0.079587
# 23          23  0.054838  0.055609  0.077309  0.006153  0.082152  0.057250
# 24          24 -0.011334 -0.013760 -0.018288  0.001936 -0.048085 -0.069387
# 25          25  0.003020 -0.002363 -0.006781 -0.011833 -0.005527 -0.001854
# 26          26 -0.004020 -0.004658 -0.009111 -0.027123 -0.022042 -0.043061
# 27          27 -0.007361 -0.010346 -0.005556 -0.015116 -0.026924 -0.027932
# 28          28 -0.006762 -0.025456 -0.046190 -0.054864 -0.037869 -0.029507
# 29          29  0.282546  0.838438  1.438664  1.851470  2.219964  2.668314
# 30          30  0.004049 -0.003124 -0.004920 -0.001557  0.013992  0.037343
# 31          31 -0.003663  0.004950 -0.003290 -0.023300 -0.057485 -0.081902
# 32          32  0.002320  0.012883  0.022324  0.015753  0.024759  0.035855
# 33          33 -0.049940 -0.068697 -0.107670 -0.127745 -0.107575 -0.101826
# 34          34  0.021067  0.020686  0.001880 -0.023290 -0.032878 -0.002605
#
#         Cr_7      Cr_8      Cr_9  ...     Pb_16     Pb_17     Pb_18     Pb_19  \
# 0  -0.132136 -0.122575 -0.117045  ... -0.101158 -0.040047 -0.065134 -0.063371
# 1   0.000590 -0.001040 -0.003490  ...  0.040723  0.054926  0.072233  0.082767
# 2  -0.026060 -0.041183 -0.037491  ...  0.040236  0.064601  0.071376  0.082908
# 3  -0.083667 -0.108718 -0.134364  ...  0.022424  0.008823  0.015268  0.044369
# 4  -0.105359 -0.111896 -0.123708  ...  0.057861  0.072787  0.072266  0.060002
# 5  -0.014598 -0.027778 -0.029178  ... -0.029652 -0.036447 -0.025205 -0.017715
# 6  -0.014056 -0.016214 -0.028914  ... -0.121631 -0.115916 -0.127389 -0.130516
# 7   0.086291  0.085967  0.097930  ...  0.015231  0.037700  0.050208  0.057160
# 8   0.034049  0.041776  0.045218  ... -0.110729 -0.095215 -0.153605 -0.111848
# 9   0.100423  0.090659  0.039625  ...  0.640071  0.528432  0.539486  0.541403
# 10  0.084923  0.125588  0.137170  ...  0.239615  0.287563  0.275400  0.260364
# 11  0.000686 -0.016918  0.011127  ... -0.155801 -0.178601 -0.171625 -0.169689
# 12 -0.002589  0.015806 -0.000572  ...  2.342514  2.477954  2.687897  2.935550
# 13 -0.068778 -0.062267 -0.047344  ... -0.140690 -0.135009 -0.129492 -0.122415
# 14  0.260757  0.403448  0.527766  ... -0.268453 -0.241566 -0.207305 -0.164427
# 15 -0.020450 -0.017446 -0.011336  ... -0.070545 -0.073817 -0.070488 -0.068774
# 16 -0.054527 -0.070576 -0.068425  ... -0.011107 -0.015608 -0.012446 -0.014013
# 17  0.046252  0.053105  0.034754  ... -0.072761 -0.087926 -0.083838 -0.051208
# 18 -0.206952 -0.280470 -0.340175  ... -0.118749 -0.074697 -0.096425 -0.114998
# 19 -0.004470 -0.005699 -0.004016  ...  0.068231  0.030440  0.032421  0.036814
# 20  0.395403  0.697447  1.073004  ... -0.106611 -0.076238 -0.050907 -0.005622
# 21 -0.015744 -0.060802 -0.075701  ...  0.013021 -0.005742 -0.012607 -0.024381
# 22 -0.090681 -0.089700 -0.108901  ... -0.059960 -0.071132 -0.079073 -0.077940
# 23  0.074084  0.134766  0.116965  ...  0.385378  0.301864  0.371647  0.541522
# 24 -0.072257 -0.083052 -0.081264  ...  0.144326  0.161288  0.130839  0.120121
# 25  0.005252  0.011735  0.016161  ...  0.091422  0.096806  0.102609  0.122400
# 26 -0.061232 -0.078997 -0.067378  ...  0.168111  0.203775  0.186334  0.165178
# 27 -0.030587 -0.032399 -0.031483  ... -0.041628 -0.034605 -0.026061 -0.034809
# 28 -0.022583 -0.007428 -0.000450  ...  0.013604  0.017593  0.023171  0.046185
# 29  2.999381  3.064485  3.147486  ...  0.217670  0.216407  0.202742  0.178578
# 30  0.054466  0.055461  0.066106  ...  0.089532  0.077952  0.076225  0.073630
# 31 -0.121509 -0.136188 -0.138194  ... -0.057388 -0.048425 -0.050601 -0.068077
# 32  0.000152 -0.051221 -0.056932  ...  0.151727  0.138876  0.186236  0.146441
# 33 -0.033897  0.009961  0.005269  ... -0.012536  0.010919  0.011992  0.036137
# 34 -0.055054 -0.045300 -0.037887  ...  2.488647  2.333170  2.408440  2.542821
#
#        Pb_20  enriched_metal  Cluster  center_of_mass  highest_peak  \
# 0  -0.090925              Cd        1        4.369825             5
# 1   0.082234              Zn        1        3.710150             5
# 2   0.099433              Cd        1        3.219017             6
# 3   0.120039              Zn        5        2.894733             4
# 4   0.031320              Zn        1        1.415268             1
# 5  -0.006617              Zn        1        4.569394             1
# 6  -0.127184              Cu        1        2.548324             3
# 7   0.083771              Zn        1        2.942274             6
# 8  -0.072307              Cu        1        2.862103             4
# 9   0.563479              Cu        6        3.409362             6
# 10  0.263688              Zn        0        1.380981             2
# 11 -0.164404              Zn        1        3.941499             6
# 12  3.285589              Pb        1        4.354845             6
# 13 -0.135776              Zn        1        3.753834             6
# 14 -0.129330              Cd        1        3.109353             5
# 15 -0.062571              Zn        1        1.626167             4
# 16 -0.015094              Zn        1        1.592862             1
# 17  0.020072              Fe        1        1.827821             2
# 18 -0.161622              Cu        1        3.843023             6
# 19  0.069356              Zn        1        2.668649             3
# 20  0.017710              Fe        1        3.364224             6
# 21 -0.041273              Fe        1     -131.269878             6
# 22 -0.065364              Cd        4        3.041297             5
# 23  1.050686              Fe        1        3.595829             6
# 24  0.090994              Fe        1        4.258559             6
# 25  0.142175              Fe        1        4.040072             6
# 26  0.091913              Zn        5        3.954016             6
# 27 -0.056635              Zn        1        4.027564             6
# 28  0.089531              Zn        1        3.359862             6
# 29  0.162006              Cr        2        3.386414             6
# 30  0.067742              Fe        1       -1.191210             5
# 31 -0.129390              Cd        1        2.837589             6
# 32  0.107336              Cd        1        3.799143             6
# 33  0.037548              Cd        1        3.345933             6
# 34  2.675084              Pb        3        3.356270             6
#
#        shape_classification
# 0          Mixed Activation
# 1         Steady Activation
# 2         Steady Activation
# 3   Intermediate Activation
# 4           Fast Activation
# 5          Mixed Activation
# 6           Fast Activation
# 7         Steady Activation
# 8   Intermediate Activation
# 9         Steady Activation
# 10          Fast Activation
# 11        Steady Activation
# 12         Mixed Activation
# 13        Steady Activation
# 14        Steady Activation
# 15  Intermediate Activation
# 16          Fast Activation
# 17          Fast Activation
# 18        Steady Activation
# 19          Fast Activation
# 20        Steady Activation
# 21        Steady Activation
# 22        Steady Activation
# 23        Steady Activation
# 24         Mixed Activation
# 25         Mixed Activation
# 26        Steady Activation
# 27         Mixed Activation
# 28        Steady Activation
# 29        Steady Activation
# 30        Steady Activation
# 31        Steady Activation
# 32        Steady Activation
# 33        Steady Activation
# 34        Steady Activation
#
# [35 rows x 126 columns]

# %%
import matplotlib.pyplot as plt

# Define the data
induction_dataset = ["Pb", "Zn", "Fe", "Cd", "Cr", "Pb", "Fe", "Zn", "Zn", "Zn", "Cu", "Cr", "Zn", "Fe", "Cu"]
post_induction_dataset = ["Cu", "Zn", "Zn", "Zn", "Zn", "Zn", "Fe", "Fe", "Cd", "Cu", "Zn", "Cu", "Pb", "Zn", "Cr", "Zn", "Zn", "Cr", "Fe", "Zn", "Cr", "Cr", "Cd", "Fe", "Fe", "Fe", "Zn", "Zn", "Zn", "Cr", "Fe", "Zn", "Cd", "Cd", "Pb"]

# Group the iModulons by heavy metal and get the iModulon numbers for each group
induction_groups = {metal: [i for i, x in enumerate(induction_dataset) if x == metal] for metal in set(induction_dataset)}
post_induction_groups = {metal: [i for i, x in enumerate(post_induction_dataset) if x == metal] for metal in set(post_induction_dataset)}

# Create bar plots
fig, ax = plt.subplots(1, 2, figsize=(14, 7))

# Define a color map
colors = plt.cm.Paired(range(len(induction_groups)))

# Plot bar chart for induction dataset
bars1 = ax[0].bar(induction_groups.keys(), [len(v) for v in induction_groups.values()], color=colors)
ax[0].set_title('Induction Dataset')
ax[0].set_ylabel('Number of iModulons')
ax[0].set_xlabel('Heavy Metal')

# Plot bar chart for post-induction dataset
bars2 = ax[1].bar(post_induction_groups.keys(), [len(v) for v in post_induction_groups.values()], color=colors)
ax[1].set_title('Post-Induction Dataset')
ax[1].set_ylabel('Number of iModulons')
ax[1].set_xlabel('Heavy Metal')

# Add iModulon numbers as annotations within the bars
for i, bar in enumerate(bars1):
    metal = list(induction_groups.keys())[i]
    imodulons = 'iModulons: ' + ', '.join(map(str, induction_groups[metal]))
    ax[0].text(bar.get_x() + bar.get_width() / 2, bar.get_height() / 2, imodulons, ha='center', va='center', rotation=90, color='black', fontsize=10)

for i, bar in enumerate(bars2):
    metal = list(post_induction_groups.keys())[i]
    imodulons = 'iMod: ' + ', '.join(map(str, post_induction_groups[metal]))
    ax[1].text(bar.get_x() + bar.get_width() / 2, bar.get_height() / 2, imodulons, ha='center', va='center', rotation=90, color='black', fontsize=10)

# Display the plot
plt.tight_layout()
plt.savefig('iModulon_classification_barplot.png')  # Save the plot as a PNG file

plt.show()
